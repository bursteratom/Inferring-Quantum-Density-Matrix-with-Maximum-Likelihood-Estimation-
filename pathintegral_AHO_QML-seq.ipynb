# %%
from __future__ import print_function
import pylab

import numpy as np

import matplotlib.pyplot as plt
import time
import os
import pickle


import pandas as pd

import random

#from category_encoders import *

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

plt.style.use('seaborn-white')

pylab.ion()

# %%
import scipy.integrate as integrate
from numpy import sqrt, sin, cos, pi, tan, sinh, cosh, exp, tanh, log, log10
import scipy.special as ssf
import math

# %%
'''
from multiprocessing import Pool
from multiprocessing import cpu_count
import emcee
from tqdm import tqdm

ncpu = cpu_count()
print("{0} CPUs".format(ncpu))
'''
# Out:
# '\nfrom multiprocessing import Pool\nfrom multiprocessing import cpu_count\nimport emcee\nfrom tqdm import tqdm\n\nncpu = cpu_count()\nprint("{0} CPUs".format(ncpu))\n'

# %%
def make_lower(side_len):
    mask = np.zeros((side_len, side_len), dtype = np.intc)
    for i in range(side_len):
        for j in range(i+1):
            mask[i, j] = 1
    mask = torch.from_numpy(mask)
    return mask

def make_diag(side_len):
    mask = np.zeros((side_len, side_len), dtype = np.intc)
    for i in range(side_len):
        mask[i, i] = 1
    mask = torch.from_numpy(mask)
    return mask

# %%
def psiHOpoint(n, x):
    return exp(-0.5*x*x)*ssf.hermite(n)(x)/sqrt(math.factorial(n)*sqrt(pi)*2**n)

def psiHO(n, x):
    x=np.array(x)
    return exp(-0.5*x*x)*ssf.hermite(n)(x)/sqrt(math.factorial(n)*sqrt(pi)*2**n)

def psiHOall(n, x):
    return np.array([psiHO(i, x) for i in range(n+1)])

def HM(n, x):
    return np.array([psiHO(i, x) for i in range(n+1)]).T

def FM(k, L, x): #k Fourier modes in the interval (-L,L)
    x=np.array(x)
    xkmat = np.reshape(x, [len(x),1])*np.array(range(1,k+1))
    zeromode = 1/sqrt(2*L)*np.ones([len(x),1])
    cosmodes = cos(xkmat*pi/L)/sqrt(L)
    sinmodes = sin(xkmat*pi/L)/sqrt(L)
    return np.concatenate((zeromode,cosmodes,sinmodes),axis=1)

def FCpsiHO(n, k, L) :#k Fourier coefficients for the nth harmonic oscillator wavefunction in (-L,L)
    coeff0 = np.array([integrate.quad(lambda x: psiHOpoint(n, x)/sqrt(2*L), -L, L)[0]])
    coeffcos = np.array([integrate.quad(lambda x: psiHOpoint(n, x)*cos(x*i*pi/L)/sqrt(L), -L, L)[0] \
                         for i in range(1,k+1)])
    coeffsin = np.array([integrate.quad(lambda x: psiHOpoint(n, x)*sin(x*i*pi/L)/sqrt(L), -L, L)[0] \
                         for i in range(1,k+1)])
    return np.concatenate((coeff0,coeffcos,coeffsin))

# %%
def FM0(k, L, x): #k Fourier modes in the interval (-L,L)
    kvec = np.array(range(1,k+1))
    zeromode = 1/sqrt(2*L)
    cosmodes = cos(kvec*x*pi/L)/sqrt(L)
    sinmodes = sin(kvec*x*pi/L)/sqrt(L)
    return np.concatenate(([zeromode],cosmodes,sinmodes))

def D2FM0(k, L, x): #second derivative of k Fourier modes in the interval (-L,L)
    kvec = np.array(range(1,k+1))
    zeromode = 0
    cosmodes = -(kvec*pi/L)**2*cos(kvec*x*pi/L)/sqrt(L)
    sinmodes = -(kvec*pi/L)**2*sin(kvec*x*pi/L)/sqrt(L)
    return np.concatenate(([zeromode],cosmodes,sinmodes))

def H_HO_FM_int(k, L):
    return np.array([[integrate.quad(lambda x: FM0(k, L, x)[i]*(x**2*FM0(k, L, x)[j]- D2FM0(k, L, x)[j]), -L, L)[0] \
                     for i in range(2*k+1)] for j in range(2*k+1)])

def V_AHO(x):
    return -x**2/2-x+x**4/16

def H_AHO_FM_int(k, L, V): #V is the function that calculates the potential
    return np.array([[integrate.quad(lambda x: FM0(k, L, x)[i]*(2*V(x)*FM0(k, L, x)[j]- D2FM0(k, L, x)[j]), -L, L)[0] \
                     for i in range(2*k+1)] for j in range(2*k+1)])

# %%
def tridiag(a, b, c, k1=-1, k2=0, k3=1):
    return np.diag(a, k1) + np.diag(b, k2) + np.diag(c, k3)

def K(n):
    upper = -1*np.ones(n-1)
    center = np.concatenate(([1],2*np.ones(n-2),[1]))
    return tridiag(upper,center,upper)

def covHO(n,a):
    upper = -1*np.ones(n-1)
    center = np.concatenate(([1+a**2],(2+a**2)*np.ones(n-2),[1+a**2]))
    return np.linalg.inv(1/a*tridiag(upper,center,upper))

def solveHOE(t,a,b,T):
    t=np.array(t)
    return a*cosh(t) + (-a*cosh(T)/sinh(T) + b/sinh(T))*sinh(t)

# %%
def V_AHO(x):
    return -x**2/2-x+x**4/16

def lnprob_V(x, n, a):
    return -np.dot(x,np.dot(K(n),x))/2.0/a - np.sum(a*V_AHO(x))

# %%
T = 2

# %%
'''
T = 2
n_slice = 40
beta = 1/T
a = beta/n_slice
n_tsteps = 1000000
nwalkers = 100


path0 = np.random.rand(n_slice * nwalkers).reshape((nwalkers, n_slice))
with Pool() as pool:
    sampler = emcee.EnsembleSampler(nwalkers, n_slice, lnprob_V, args = [n_slice, a], pool=pool)
    #sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, pool=pool)
    pos, prob, state = sampler.run_mcmc(path0, 1000, progress=False)
    sampler.reset()
    
    sampler.run_mcmc(pos, n_tsteps, progress = False)
    paths = sampler.get_chain(flat = True)
    sampler.reset() 
'''
# Out:
# '\nT = 2\nn_slice = 40\nbeta = 1/T\na = beta/n_slice\nn_tsteps = 1000000\nnwalkers = 100\n\n\npath0 = np.random.rand(n_slice * nwalkers).reshape((nwalkers, n_slice))\nwith Pool() as pool:\n    sampler = emcee.EnsembleSampler(nwalkers, n_slice, lnprob_V, args = [n_slice, a], pool=pool)\n    #sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, pool=pool)\n    pos, prob, state = sampler.run_mcmc(path0, 1000, progress=False)\n    sampler.reset()\n    \n    sampler.run_mcmc(pos, n_tsteps, progress = False)\n    paths = sampler.get_chain(flat = True)\n    sampler.reset() \n'

# %%
from torch.utils.data import Dataset, DataLoader

class PathData(Dataset):
    def __init__(self, in_x, in_y):
        
        if not torch.is_tensor(in_x):
            self.in_x = torch.from_numpy(in_x)
        else:
            self.in_x = in_x
            
        if not torch.is_tensor(in_y):
            self.in_y = torch.from_numpy(in_y)
        else:
            self.in_y = in_y
        
        self.len = len(self.in_x)
        
    def __getitem__(self,index):    
            
        return self.in_x[index], self.in_y[index]
    
    def __len__(self):
        
        return self.len

# %%
class QML(nn.Module):
    def __init__(self, n_ES, n_B):
        super(QML, self).__init__()
        
        self.n_Ba = n_B
        self.n_EL = n_ES + 1
        
        self.levels = torch.nn.Parameter(torch.from_numpy(np.random.uniform(1,2,self.n_EL)))
        self.levels.requires_grad = True
        
        self.var_BaC = torch.nn.Parameter(torch.from_numpy(np.random.uniform(-1,1,[self.n_Ba, self.n_EL])))
        self.var_BaC.requires_grad = True
        
        self.mask = (make_lower(self.n_EL) - make_diag(self.n_EL) ) > 0 #convert to boolean
        self.diag = make_diag(self.n_EL) > 0 #convert to boolean   
        
    def forward(self, in_x, in_y):
        
        norms_BaC = torch.linalg.norm(self.var_BaC, dim = 0)
        var_BaC_N = self.var_BaC/norms_BaC
        logits = F.softmin(self.levels, dim = 0)
        
        c_orth = 1000
        loss_orth = c_orth * torch.mean(torch.masked_select(torch.matmul(torch.transpose(var_BaC_N, 0, 1),var_BaC_N) \
                                                                  , self.mask)**2)
        
        loss_ML = -1 * torch.mean(torch.matmul( torch.matmul(in_x, var_BaC_N) * torch.matmul(in_y, var_BaC_N) \
                    , torch.log(logits*(10**4.)+1) ) )
        
        loss = loss_orth + loss_ML
        
        return loss, loss_ML, loss_orth, self.levels, logits

# %%
def main_train_states_QML(G, in_x, in_y, batch_size = 500, epochs = 1, step = 1e-3):
    
    pathset = PathData(in_x, in_y)
    TrainLoader = DataLoader(dataset=pathset, batch_size=batch_size, shuffle = False, num_workers=2)
    
    optimiser = torch.optim.Adam(G.parameters(), lr=step)
    
    
    loss_hist = []
    loss_ML_hist = []
    loss_orth_hist = []
    
    levels_hist = []
    logits_hist = []
        
        
    
    for i in range(epochs):
        start_time = time.time()
        for id_xy, [mini_in_x, mini_in_y] in enumerate(TrainLoader):
        
            [loss, loss_ML, loss_orth, levels, logits] = G(mini_in_x, mini_in_y)
            optimiser.zero_grad()
            loss.backward()
            optimiser.step()
        
        
            loss_hist.append(loss.tolist())
            loss_ML_hist.append(loss_ML.tolist())
            loss_orth_hist.append(loss_orth.tolist())
        
            levels_hist.append(levels.tolist())
            logits_hist.append(logits.tolist())
            
           
        
            if id_xy % 1000 == 0:
                
                print('Batch number ', id_xy)
                print('Loss: ', loss)
                print('Loss_orth: ', loss_orth)
                print('Loss_ML: ', loss_ML)
                print('Logits: ', logits)
                
                end_time = time.time()
                print('Time taken: {0:.3f} seconds'.format(end_time - start_time))
                start_time = time.time()
                
                print('@----------------------------------------------------------@')
                #writer.add_summary(summary, i)
                #writer.flush()
                
            
        
                
    var_BaC = G.var_BaC
    norms_BaC = torch.linalg.norm(var_BaC, dim = 0)
    var_BaC_N = (var_BaC / norms_BaC).detach().numpy() #normalise the coefficients of basis states
    levels_hist = np.array(levels_hist)
    logits_hist = np.array(logits_hist)
    
    
    ##Sort energy levels and associated coefficients of basis states in ascending order
    fin_EL = G.levels
    fin_EL = fin_EL.detach()
    fin_logits = F.softmin(fin_EL, dim = 0)
    fin_EL = fin_EL.numpy()
    fin_logits = fin_logits.numpy()
    
    fin_EL_argsort = fin_EL.argsort()
    levels_hist = levels_hist[:, fin_EL_argsort]
    logits_hist = logits_hist[:, fin_EL_argsort]
    var_BaC_N = var_BaC_N[:, fin_EL_argsort]
    fin_EL = fin_EL[fin_EL_argsort]
    fin_logits = fin_logits[fin_EL_argsort]
    #EL_ranks = np.empty_like(fin_EL_argsort)
    #EL_ranks[fin_EL_argsort] = np.arange(len(fin_EL))
    
    return loss_hist, loss_ML_hist, loss_orth_hist, levels_hist, logits_hist, var_BaC_N, fin_EL, fin_logits

# %%
infile = "AHO_PI_MCMC_T" + str(T) + ".npy"
paths = np.load(infile)
print(paths.shape)

x = paths[:, 0]
y = paths[:, -1]

del paths
# Out:
# (100000000, 40)

# %%
n_Hm = 10
n_EL = 10

x = HM(n_Hm, x)
y = HM(n_Hm, y)

# %%
in_x = torch.from_numpy(x)
in_y = torch.from_numpy(y)

del x,y

# %%
#epochs = 1
qml_AHO_HM = QML(n_EL, n_Hm+1)

[loss_hist, loss_ML_hist, loss_orth_hist, levels_hist, logits_hist, var_HC_N, levels_fin, logits_fin] = \
            main_train_states_QML(qml_AHO_HM, in_x, in_y)
# Out:
# /home/scl489/.env/lib/python3.7/site-packages/torch/autograd/__init__.py:132: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   allow_unreachable=True)  # allow_unreachable flag
# Batch number  0
# Loss:  tensor(117.6185, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(122.7997, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.1813, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1388, 0.0809, 0.0685, 0.1163, 0.0924, 0.0628, 0.1308, 0.0769, 0.0582,
#         0.0799, 0.0945], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 0.076 seconds
# @----------------------------------------------------------@
# Batch number  1000
# Loss:  tensor(-4.2749, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.1019, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3768, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1492, 0.0684, 0.0634, 0.1598, 0.0815, 0.0620, 0.1280, 0.0720, 0.0630,
#         0.0761, 0.0767], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.858 seconds
# @----------------------------------------------------------@
# Batch number  2000
# Loss:  tensor(-4.8543, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0756, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.9299, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1629, 0.0614, 0.0603, 0.1836, 0.0829, 0.0677, 0.1224, 0.0821, 0.0441,
#         0.0660, 0.0665], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.732 seconds
# @----------------------------------------------------------@
# Batch number  3000
# Loss:  tensor(-4.1369, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0836, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2205, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1788, 0.0553, 0.0575, 0.2068, 0.0756, 0.0630, 0.1225, 0.0805, 0.0341,
#         0.0588, 0.0670], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.692 seconds
# @----------------------------------------------------------@
# Batch number  4000
# Loss:  tensor(-3.7601, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0655, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8256, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1946, 0.0538, 0.0515, 0.2168, 0.0777, 0.0626, 0.1165, 0.0806, 0.0266,
#         0.0525, 0.0668], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.772 seconds
# @----------------------------------------------------------@
# Batch number  5000
# Loss:  tensor(-4.6900, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0827, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7727, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1971, 0.0567, 0.0458, 0.2407, 0.0754, 0.0609, 0.1207, 0.0788, 0.0217,
#         0.0473, 0.0548], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.684 seconds
# @----------------------------------------------------------@
# Batch number  6000
# Loss:  tensor(-4.7045, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0909, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7953, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.2210, 0.0484, 0.0371, 0.2653, 0.0718, 0.0603, 0.1029, 0.0929, 0.0190,
#         0.0315, 0.0499], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.768 seconds
# @----------------------------------------------------------@
# Batch number  7000
# Loss:  tensor(-4.6271, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0629, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6900, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.2103, 0.0449, 0.0393, 0.2896, 0.0598, 0.0486, 0.1109, 0.1021, 0.0173,
#         0.0256, 0.0516], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.720 seconds
# @----------------------------------------------------------@
# Batch number  8000
# Loss:  tensor(-4.1474, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0590, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2064, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1949, 0.0418, 0.0384, 0.3313, 0.0554, 0.0382, 0.1169, 0.1001, 0.0126,
#         0.0225, 0.0481], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.674 seconds
# @----------------------------------------------------------@
# Batch number  9000
# Loss:  tensor(-4.2566, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0668, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3234, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1767, 0.0414, 0.0368, 0.3608, 0.0423, 0.0299, 0.1242, 0.1026, 0.0130,
#         0.0226, 0.0498], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.678 seconds
# @----------------------------------------------------------@
# Batch number  10000
# Loss:  tensor(-3.8282, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0358, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8640, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1650, 0.0341, 0.0378, 0.3929, 0.0270, 0.0217, 0.1246, 0.1129, 0.0112,
#         0.0184, 0.0543], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.681 seconds
# @----------------------------------------------------------@
# Batch number  11000
# Loss:  tensor(-4.6623, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0304, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6927, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1239, 0.0306, 0.0412, 0.4420, 0.0207, 0.0202, 0.1268, 0.1154, 0.0105,
#         0.0169, 0.0517], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.680 seconds
# @----------------------------------------------------------@
# Batch number  12000
# Loss:  tensor(-4.8027, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0198, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8224, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1159, 0.0277, 0.0388, 0.4382, 0.0157, 0.0162, 0.1371, 0.1258, 0.0100,
#         0.0144, 0.0602], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.749 seconds
# @----------------------------------------------------------@
# Batch number  13000
# Loss:  tensor(-4.4474, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0242, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4716, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1025, 0.0234, 0.0594, 0.4677, 0.0124, 0.0126, 0.1618, 0.0960, 0.0073,
#         0.0100, 0.0469], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.683 seconds
# @----------------------------------------------------------@
# Batch number  14000
# Loss:  tensor(-4.3701, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0248, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3949, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0918, 0.0231, 0.0581, 0.4589, 0.0161, 0.0188, 0.1487, 0.1129, 0.0077,
#         0.0092, 0.0548], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.702 seconds
# @----------------------------------------------------------@
# Batch number  15000
# Loss:  tensor(-4.1127, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0153, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1280, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0842, 0.0206, 0.0429, 0.4899, 0.0140, 0.0139, 0.1514, 0.1147, 0.0066,
#         0.0065, 0.0555], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.691 seconds
# @----------------------------------------------------------@
# Batch number  16000
# Loss:  tensor(-4.5861, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0198, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6059, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0875, 0.0147, 0.0496, 0.5010, 0.0119, 0.0134, 0.1514, 0.1127, 0.0052,
#         0.0046, 0.0481], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.782 seconds
# @----------------------------------------------------------@
# Batch number  17000
# Loss:  tensor(-4.0676, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0142, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0818, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0956, 0.0182, 0.0577, 0.4518, 0.0149, 0.0152, 0.1648, 0.1094, 0.0064,
#         0.0051, 0.0610], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.735 seconds
# @----------------------------------------------------------@
# Batch number  18000
# Loss:  tensor(-4.2802, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0118, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2920, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0951, 0.0165, 0.0647, 0.4382, 0.0176, 0.0207, 0.1725, 0.1060, 0.0064,
#         0.0043, 0.0580], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.695 seconds
# @----------------------------------------------------------@
# Batch number  19000
# Loss:  tensor(-4.3143, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0186, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3329, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0915, 0.0139, 0.0592, 0.4467, 0.0149, 0.0203, 0.1769, 0.1142, 0.0057,
#         0.0037, 0.0530], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.699 seconds
# @----------------------------------------------------------@
# Batch number  20000
# Loss:  tensor(-4.7589, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0101, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7689, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0913, 0.0134, 0.0455, 0.4672, 0.0131, 0.0180, 0.1783, 0.1114, 0.0055,
#         0.0031, 0.0534], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.697 seconds
# @----------------------------------------------------------@
# Batch number  21000
# Loss:  tensor(-4.2250, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0084, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2333, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0888, 0.0149, 0.0507, 0.4461, 0.0160, 0.0199, 0.1719, 0.1188, 0.0068,
#         0.0033, 0.0628], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.696 seconds
# @----------------------------------------------------------@
# Batch number  22000
# Loss:  tensor(-5.0673, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0163, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.0836, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0896, 0.0130, 0.0565, 0.4408, 0.0131, 0.0197, 0.1661, 0.1316, 0.0054,
#         0.0024, 0.0616], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.777 seconds
# @----------------------------------------------------------@
# Batch number  23000
# Loss:  tensor(-4.3880, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0135, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4015, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0769, 0.0107, 0.0368, 0.4649, 0.0120, 0.0174, 0.1815, 0.1308, 0.0047,
#         0.0022, 0.0621], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.716 seconds
# @----------------------------------------------------------@
# Batch number  24000
# Loss:  tensor(-4.1543, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0090, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1633, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0851, 0.0101, 0.0372, 0.4715, 0.0120, 0.0163, 0.1940, 0.1157, 0.0043,
#         0.0019, 0.0519], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.694 seconds
# @----------------------------------------------------------@
# Batch number  25000
# Loss:  tensor(-4.5530, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0119, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5649, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0861, 0.0087, 0.0448, 0.4697, 0.0137, 0.0215, 0.1749, 0.1226, 0.0041,
#         0.0017, 0.0522], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.670 seconds
# @----------------------------------------------------------@
# Batch number  26000
# Loss:  tensor(-4.3720, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0188, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3908, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0827, 0.0094, 0.0333, 0.4624, 0.0118, 0.0162, 0.1746, 0.1408, 0.0042,
#         0.0017, 0.0628], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.688 seconds
# @----------------------------------------------------------@
# Batch number  27000
# Loss:  tensor(-4.2150, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0201, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2351, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0780, 0.0097, 0.0365, 0.4387, 0.0128, 0.0173, 0.1887, 0.1444, 0.0041,
#         0.0018, 0.0680], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.972 seconds
# @----------------------------------------------------------@
# Batch number  28000
# Loss:  tensor(-4.2212, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0107, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2319, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0844, 0.0090, 0.0391, 0.4566, 0.0104, 0.0167, 0.1876, 0.1323, 0.0039,
#         0.0015, 0.0585], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.685 seconds
# @----------------------------------------------------------@
# Batch number  29000
# Loss:  tensor(-4.4233, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0126, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4359, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0791, 0.0084, 0.0348, 0.4875, 0.0102, 0.0176, 0.1807, 0.1254, 0.0038,
#         0.0013, 0.0511], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.664 seconds
# @----------------------------------------------------------@
# Batch number  30000
# Loss:  tensor(-3.9518, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0191, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.9709, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0832, 0.0070, 0.0375, 0.4600, 0.0105, 0.0196, 0.2034, 0.1231, 0.0033,
#         0.0012, 0.0511], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.996 seconds
# @----------------------------------------------------------@
# Batch number  31000
# Loss:  tensor(-4.0042, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0089, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0131, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1008, 0.0074, 0.0427, 0.4318, 0.0117, 0.0215, 0.2025, 0.1179, 0.0030,
#         0.0011, 0.0598], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.898 seconds
# @----------------------------------------------------------@
# Batch number  32000
# Loss:  tensor(-4.8133, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0352, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8485, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0921, 0.0056, 0.0340, 0.4665, 0.0084, 0.0145, 0.1993, 0.1205, 0.0021,
#         0.0007, 0.0563], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.948 seconds
# @----------------------------------------------------------@
# Batch number  33000
# Loss:  tensor(-4.0906, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0105, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1011, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0870, 0.0068, 0.0374, 0.4576, 0.0099, 0.0183, 0.2016, 0.1177, 0.0022,
#         0.0008, 0.0606], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.897 seconds
# @----------------------------------------------------------@
# Batch number  34000
# Loss:  tensor(-4.6051, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0096, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6146, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0735, 0.0077, 0.0370, 0.4585, 0.0128, 0.0207, 0.2047, 0.1201, 0.0027,
#         0.0010, 0.0612], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.903 seconds
# @----------------------------------------------------------@
# Batch number  35000
# Loss:  tensor(-5.5824, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0066, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.5890, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0705, 0.0072, 0.0342, 0.4637, 0.0118, 0.0194, 0.2117, 0.1215, 0.0032,
#         0.0012, 0.0556], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.907 seconds
# @----------------------------------------------------------@
# Batch number  36000
# Loss:  tensor(-4.1343, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0069, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1412, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0814, 0.0075, 0.0359, 0.4464, 0.0083, 0.0165, 0.2101, 0.1260, 0.0029,
#         0.0010, 0.0641], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 3.004 seconds
# @----------------------------------------------------------@
# Batch number  37000
# Loss:  tensor(-4.4336, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0111, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4447, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0662, 0.0065, 0.0335, 0.4925, 0.0077, 0.0161, 0.1918, 0.1244, 0.0022,
#         0.0008, 0.0582], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 3.052 seconds
# @----------------------------------------------------------@
# Batch number  38000
# Loss:  tensor(-4.7790, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0102, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7892, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0757, 0.0063, 0.0333, 0.4534, 0.0098, 0.0183, 0.2208, 0.1229, 0.0023,
#         0.0009, 0.0563], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.915 seconds
# @----------------------------------------------------------@
# Batch number  39000
# Loss:  tensor(-4.4027, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0061, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4088, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0966, 0.0063, 0.0401, 0.4348, 0.0099, 0.0220, 0.2146, 0.1144, 0.0023,
#         0.0009, 0.0583], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.953 seconds
# @----------------------------------------------------------@
# Batch number  40000
# Loss:  tensor(-4.6909, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0158, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7068, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0983, 0.0072, 0.0361, 0.4558, 0.0119, 0.0213, 0.2002, 0.1124, 0.0031,
#         0.0011, 0.0525], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.991 seconds
# @----------------------------------------------------------@
# Batch number  41000
# Loss:  tensor(-4.2251, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0173, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2423, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0899, 0.0076, 0.0365, 0.4528, 0.0117, 0.0220, 0.1975, 0.1167, 0.0036,
#         0.0011, 0.0606], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.882 seconds
# @----------------------------------------------------------@
# Batch number  42000
# Loss:  tensor(-4.5052, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0164, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5216, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0787, 0.0077, 0.0346, 0.4504, 0.0107, 0.0194, 0.2129, 0.1228, 0.0040,
#         0.0011, 0.0577], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.938 seconds
# @----------------------------------------------------------@
# Batch number  43000
# Loss:  tensor(-4.4053, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0185, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4238, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0892, 0.0061, 0.0360, 0.4677, 0.0098, 0.0186, 0.1989, 0.1155, 0.0035,
#         0.0010, 0.0538], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.927 seconds
# @----------------------------------------------------------@
# Batch number  44000
# Loss:  tensor(-4.6209, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0108, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6317, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0779, 0.0053, 0.0346, 0.4586, 0.0091, 0.0169, 0.2235, 0.1135, 0.0026,
#         0.0008, 0.0571], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.964 seconds
# @----------------------------------------------------------@
# Batch number  45000
# Loss:  tensor(-4.2514, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0158, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2672, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0682, 0.0052, 0.0276, 0.5027, 0.0082, 0.0139, 0.2085, 0.1127, 0.0024,
#         0.0008, 0.0499], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.881 seconds
# @----------------------------------------------------------@
# Batch number  46000
# Loss:  tensor(-4.3263, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0056, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3319, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0800, 0.0049, 0.0300, 0.4656, 0.0073, 0.0141, 0.2215, 0.1190, 0.0023,
#         0.0008, 0.0545], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.893 seconds
# @----------------------------------------------------------@
# Batch number  47000
# Loss:  tensor(-4.3414, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0108, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3523, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0787, 0.0051, 0.0306, 0.4712, 0.0081, 0.0166, 0.2240, 0.1117, 0.0025,
#         0.0008, 0.0507], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.940 seconds
# @----------------------------------------------------------@
# Batch number  48000
# Loss:  tensor(-4.1826, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0069, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1894, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0741, 0.0065, 0.0313, 0.4664, 0.0100, 0.0184, 0.2109, 0.1256, 0.0029,
#         0.0009, 0.0530], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.844 seconds
# @----------------------------------------------------------@
# Batch number  49000
# Loss:  tensor(-4.6641, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0036, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6678, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0562, 0.0052, 0.0233, 0.5147, 0.0074, 0.0127, 0.2146, 0.1131, 0.0021,
#         0.0006, 0.0500], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.957 seconds
# @----------------------------------------------------------@
# Batch number  50000
# Loss:  tensor(-4.5308, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0042, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5350, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0718, 0.0060, 0.0330, 0.4624, 0.0084, 0.0178, 0.2188, 0.1204, 0.0024,
#         0.0007, 0.0583], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.894 seconds
# @----------------------------------------------------------@
# Batch number  51000
# Loss:  tensor(-5.2489, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0050, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.2539, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0828, 0.0047, 0.0302, 0.4804, 0.0073, 0.0145, 0.2163, 0.1134, 0.0021,
#         0.0006, 0.0478], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.879 seconds
# @----------------------------------------------------------@
# Batch number  52000
# Loss:  tensor(-4.0961, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0047, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1008, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0798, 0.0073, 0.0377, 0.4623, 0.0112, 0.0216, 0.2000, 0.1183, 0.0029,
#         0.0009, 0.0580], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.900 seconds
# @----------------------------------------------------------@
# Batch number  53000
# Loss:  tensor(-4.8325, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0085, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8411, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0747, 0.0069, 0.0325, 0.4742, 0.0102, 0.0193, 0.2139, 0.1129, 0.0027,
#         0.0008, 0.0519], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.894 seconds
# @----------------------------------------------------------@
# Batch number  54000
# Loss:  tensor(-4.7886, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0069, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7954, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0925, 0.0073, 0.0397, 0.4360, 0.0104, 0.0216, 0.2130, 0.1169, 0.0029,
#         0.0010, 0.0587], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.965 seconds
# @----------------------------------------------------------@
# Batch number  55000
# Loss:  tensor(-4.5852, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0090, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5942, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0762, 0.0092, 0.0418, 0.4222, 0.0141, 0.0272, 0.2128, 0.1246, 0.0037,
#         0.0013, 0.0669], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.899 seconds
# @----------------------------------------------------------@
# Batch number  56000
# Loss:  tensor(-4.6779, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0049, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6828, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0889, 0.0070, 0.0343, 0.4401, 0.0099, 0.0185, 0.2128, 0.1260, 0.0030,
#         0.0010, 0.0584], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.892 seconds
# @----------------------------------------------------------@
# Batch number  57000
# Loss:  tensor(-3.7960, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0081, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8042, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0717, 0.0060, 0.0328, 0.5017, 0.0084, 0.0187, 0.2129, 0.0974, 0.0029,
#         0.0009, 0.0466], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 3.111 seconds
# @----------------------------------------------------------@
# Batch number  58000
# Loss:  tensor(-3.9010, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0088, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.9097, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0877, 0.0063, 0.0348, 0.4652, 0.0089, 0.0184, 0.2043, 0.1155, 0.0028,
#         0.0008, 0.0552], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.729 seconds
# @----------------------------------------------------------@
# Batch number  59000
# Loss:  tensor(-4.0318, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0067, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0385, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0876, 0.0068, 0.0347, 0.4568, 0.0113, 0.0217, 0.2210, 0.1055, 0.0032,
#         0.0011, 0.0503], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.736 seconds
# @----------------------------------------------------------@
# Batch number  60000
# Loss:  tensor(-4.4613, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0083, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4696, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0733, 0.0071, 0.0324, 0.4599, 0.0114, 0.0203, 0.2248, 0.1144, 0.0035,
#         0.0012, 0.0516], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.669 seconds
# @----------------------------------------------------------@
# Batch number  61000
# Loss:  tensor(-4.6424, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0064, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6488, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0871, 0.0059, 0.0357, 0.4670, 0.0100, 0.0193, 0.2105, 0.1104, 0.0032,
#         0.0011, 0.0497], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 3.024 seconds
# @----------------------------------------------------------@
# Batch number  62000
# Loss:  tensor(-4.2570, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0066, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2636, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.1047, 0.0062, 0.0401, 0.4359, 0.0101, 0.0213, 0.2050, 0.1163, 0.0034,
#         0.0012, 0.0556], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.913 seconds
# @----------------------------------------------------------@
# Batch number  63000
# Loss:  tensor(-4.5908, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0088, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5996, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0989, 0.0066, 0.0373, 0.4430, 0.0115, 0.0218, 0.2038, 0.1185, 0.0037,
#         0.0012, 0.0537], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.895 seconds
# @----------------------------------------------------------@
# Batch number  64000
# Loss:  tensor(-3.5762, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0082, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.5844, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0812, 0.0076, 0.0357, 0.4535, 0.0125, 0.0216, 0.2019, 0.1242, 0.0039,
#         0.0013, 0.0565], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.946 seconds
# @----------------------------------------------------------@
# Batch number  65000
# Loss:  tensor(-3.7889, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0040, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.7928, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0935, 0.0056, 0.0290, 0.4626, 0.0086, 0.0155, 0.2095, 0.1231, 0.0027,
#         0.0010, 0.0490], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.932 seconds
# @----------------------------------------------------------@
# Batch number  66000
# Loss:  tensor(-4.4612, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0062, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4674, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0774, 0.0063, 0.0324, 0.4669, 0.0111, 0.0197, 0.2152, 0.1167, 0.0028,
#         0.0009, 0.0505], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.898 seconds
# @----------------------------------------------------------@
# Batch number  67000
# Loss:  tensor(-4.2193, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0042, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2235, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0863, 0.0073, 0.0366, 0.4781, 0.0127, 0.0224, 0.1950, 0.1057, 0.0032,
#         0.0011, 0.0517], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.899 seconds
# @----------------------------------------------------------@
# Batch number  68000
# Loss:  tensor(-4.5312, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0051, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5362, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0870, 0.0058, 0.0340, 0.4718, 0.0092, 0.0178, 0.2148, 0.1055, 0.0025,
#         0.0009, 0.0506], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.790 seconds
# @----------------------------------------------------------@
# Batch number  69000
# Loss:  tensor(-4.3704, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0042, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3745, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0729, 0.0067, 0.0375, 0.4592, 0.0104, 0.0207, 0.2125, 0.1207, 0.0028,
#         0.0009, 0.0556], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.752 seconds
# @----------------------------------------------------------@
# Batch number  70000
# Loss:  tensor(-4.2720, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0093, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2813, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0865, 0.0066, 0.0369, 0.4583, 0.0097, 0.0192, 0.2050, 0.1171, 0.0029,
#         0.0009, 0.0570], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.695 seconds
# @----------------------------------------------------------@
# Batch number  71000
# Loss:  tensor(-4.1849, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0034, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1882, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0951, 0.0055, 0.0342, 0.4491, 0.0084, 0.0182, 0.2174, 0.1160, 0.0024,
#         0.0008, 0.0528], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 3.027 seconds
# @----------------------------------------------------------@
# Batch number  72000
# Loss:  tensor(-4.6815, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0108, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6923, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0677, 0.0046, 0.0239, 0.4842, 0.0067, 0.0133, 0.2239, 0.1239, 0.0022,
#         0.0007, 0.0492], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.772 seconds
# @----------------------------------------------------------@
# Batch number  73000
# Loss:  tensor(-4.5078, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0064, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5142, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0772, 0.0055, 0.0292, 0.4650, 0.0083, 0.0166, 0.2249, 0.1214, 0.0026,
#         0.0008, 0.0484], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.684 seconds
# @----------------------------------------------------------@
# Batch number  74000
# Loss:  tensor(-4.4859, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0056, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4915, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0710, 0.0053, 0.0284, 0.4807, 0.0091, 0.0184, 0.2251, 0.1120, 0.0026,
#         0.0008, 0.0467], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.737 seconds
# @----------------------------------------------------------@
# Batch number  75000
# Loss:  tensor(-4.3599, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0059, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3658, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0782, 0.0055, 0.0337, 0.4641, 0.0092, 0.0181, 0.2134, 0.1190, 0.0028,
#         0.0008, 0.0551], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.877 seconds
# @----------------------------------------------------------@
# Batch number  76000
# Loss:  tensor(-4.5692, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0119, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5811, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0911, 0.0046, 0.0317, 0.4644, 0.0073, 0.0155, 0.2102, 0.1170, 0.0022,
#         0.0005, 0.0554], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.903 seconds
# @----------------------------------------------------------@
# Batch number  77000
# Loss:  tensor(-4.4952, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0034, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4986, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0757, 0.0053, 0.0349, 0.4759, 0.0093, 0.0186, 0.2056, 0.1153, 0.0024,
#         0.0006, 0.0566], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.906 seconds
# @----------------------------------------------------------@
# Batch number  78000
# Loss:  tensor(-4.5323, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0079, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5402, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0809, 0.0050, 0.0325, 0.4613, 0.0085, 0.0173, 0.2220, 0.1172, 0.0022,
#         0.0006, 0.0525], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.905 seconds
# @----------------------------------------------------------@
# Batch number  79000
# Loss:  tensor(-4.8101, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0046, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8147, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0710, 0.0058, 0.0313, 0.4819, 0.0098, 0.0192, 0.2228, 0.1087, 0.0028,
#         0.0008, 0.0459], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.961 seconds
# @----------------------------------------------------------@
# Batch number  80000
# Loss:  tensor(-4.3122, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0054, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3176, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0844, 0.0059, 0.0375, 0.4710, 0.0109, 0.0204, 0.1974, 0.1085, 0.0030,
#         0.0009, 0.0600], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.951 seconds
# @----------------------------------------------------------@
# Batch number  81000
# Loss:  tensor(-4.2760, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0060, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2820, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0745, 0.0070, 0.0330, 0.4823, 0.0119, 0.0197, 0.2110, 0.1087, 0.0032,
#         0.0010, 0.0478], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.960 seconds
# @----------------------------------------------------------@
# Batch number  82000
# Loss:  tensor(-4.8871, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0055, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8926, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0828, 0.0061, 0.0370, 0.4464, 0.0104, 0.0208, 0.2135, 0.1226, 0.0031,
#         0.0008, 0.0565], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.939 seconds
# @----------------------------------------------------------@
# Batch number  83000
# Loss:  tensor(-4.7491, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0076, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7567, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0684, 0.0063, 0.0302, 0.4679, 0.0096, 0.0185, 0.2262, 0.1173, 0.0028,
#         0.0007, 0.0521], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.957 seconds
# @----------------------------------------------------------@
# Batch number  84000
# Loss:  tensor(-4.6240, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0053, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6293, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0588, 0.0045, 0.0249, 0.5390, 0.0081, 0.0139, 0.2105, 0.0949, 0.0022,
#         0.0006, 0.0425], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.966 seconds
# @----------------------------------------------------------@
# Batch number  85000
# Loss:  tensor(-4.4546, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0116, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4662, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0739, 0.0046, 0.0312, 0.4761, 0.0087, 0.0166, 0.2196, 0.1160, 0.0023,
#         0.0006, 0.0504], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.896 seconds
# @----------------------------------------------------------@
# Batch number  86000
# Loss:  tensor(-4.5845, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0040, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5885, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0647, 0.0049, 0.0270, 0.5141, 0.0089, 0.0165, 0.2112, 0.1047, 0.0026,
#         0.0006, 0.0447], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.909 seconds
# @----------------------------------------------------------@
# Batch number  87000
# Loss:  tensor(-5.0181, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0089, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.0270, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0660, 0.0059, 0.0314, 0.4815, 0.0101, 0.0184, 0.2194, 0.1130, 0.0029,
#         0.0007, 0.0508], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.934 seconds
# @----------------------------------------------------------@
# Batch number  88000
# Loss:  tensor(-4.7390, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0093, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7483, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0687, 0.0066, 0.0319, 0.4865, 0.0107, 0.0187, 0.2075, 0.1103, 0.0030,
#         0.0009, 0.0552], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.896 seconds
# @----------------------------------------------------------@
# Batch number  89000
# Loss:  tensor(-4.1601, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0100, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1700, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0784, 0.0069, 0.0322, 0.4723, 0.0106, 0.0186, 0.2150, 0.1110, 0.0029,
#         0.0009, 0.0511], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.958 seconds
# @----------------------------------------------------------@
# Batch number  90000
# Loss:  tensor(-4.2900, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0111, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3012, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0795, 0.0065, 0.0308, 0.4748, 0.0099, 0.0181, 0.2078, 0.1167, 0.0030,
#         0.0007, 0.0522], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.908 seconds
# @----------------------------------------------------------@
# Batch number  91000
# Loss:  tensor(-5.0293, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0081, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.0374, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0712, 0.0051, 0.0282, 0.4793, 0.0094, 0.0181, 0.2231, 0.1152, 0.0026,
#         0.0006, 0.0471], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.903 seconds
# @----------------------------------------------------------@
# Batch number  92000
# Loss:  tensor(-4.1696, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0112, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.1808, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0787, 0.0047, 0.0315, 0.4701, 0.0091, 0.0187, 0.2137, 0.1181, 0.0025,
#         0.0005, 0.0523], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.982 seconds
# @----------------------------------------------------------@
# Batch number  93000
# Loss:  tensor(-4.5066, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0116, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5183, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0903, 0.0052, 0.0361, 0.4366, 0.0103, 0.0205, 0.2124, 0.1284, 0.0024,
#         0.0006, 0.0572], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.805 seconds
# @----------------------------------------------------------@
# Batch number  94000
# Loss:  tensor(-4.3359, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0055, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3414, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0758, 0.0054, 0.0341, 0.4598, 0.0101, 0.0184, 0.2216, 0.1189, 0.0024,
#         0.0006, 0.0530], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.780 seconds
# @----------------------------------------------------------@
# Batch number  95000
# Loss:  tensor(-4.9389, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0097, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.9486, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0560, 0.0049, 0.0278, 0.5005, 0.0082, 0.0161, 0.2323, 0.1049, 0.0024,
#         0.0006, 0.0463], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.710 seconds
# @----------------------------------------------------------@
# Batch number  96000
# Loss:  tensor(-4.6020, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0136, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6156, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0694, 0.0056, 0.0301, 0.4915, 0.0096, 0.0182, 0.2126, 0.1090, 0.0028,
#         0.0007, 0.0506], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.676 seconds
# @----------------------------------------------------------@
# Batch number  97000
# Loss:  tensor(-3.8146, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0064, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8210, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0774, 0.0044, 0.0303, 0.4663, 0.0074, 0.0152, 0.2149, 0.1329, 0.0021,
#         0.0005, 0.0486], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.681 seconds
# @----------------------------------------------------------@
# Batch number  98000
# Loss:  tensor(-4.3183, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0078, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3261, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0727, 0.0067, 0.0318, 0.4656, 0.0102, 0.0187, 0.2150, 0.1195, 0.0031,
#         0.0007, 0.0560], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.689 seconds
# @----------------------------------------------------------@
# Batch number  99000
# Loss:  tensor(-4.9600, dtype=torch.float64, grad_fn=<AddBackward0>)
# ...
# Loss_orth:  tensor(0.0048, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2514, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0789, 0.0066, 0.0348, 0.4499, 0.0132, 0.0222, 0.2088, 0.1257, 0.0034,
#         0.0006, 0.0560], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.734 seconds
# @----------------------------------------------------------@
# Batch number  168000
# Loss:  tensor(-4.0448, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0067, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0514, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0647, 0.0065, 0.0292, 0.5025, 0.0109, 0.0177, 0.2110, 0.1079, 0.0033,
#         0.0007, 0.0458], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.707 seconds
# @----------------------------------------------------------@
# Batch number  169000
# Loss:  tensor(-4.3935, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0091, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4026, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0794, 0.0069, 0.0346, 0.4584, 0.0120, 0.0205, 0.2116, 0.1164, 0.0037,
#         0.0008, 0.0555], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.780 seconds
# @----------------------------------------------------------@
# Batch number  170000
# Loss:  tensor(-4.5634, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0100, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5734, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0764, 0.0053, 0.0259, 0.4827, 0.0092, 0.0151, 0.2160, 0.1161, 0.0031,
#         0.0007, 0.0494], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.675 seconds
# @----------------------------------------------------------@
# Batch number  171000
# Loss:  tensor(-4.2578, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0054, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2632, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0820, 0.0056, 0.0351, 0.4749, 0.0104, 0.0205, 0.2010, 0.1088, 0.0032,
#         0.0007, 0.0577], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.764 seconds
# @----------------------------------------------------------@
# Batch number  172000
# Loss:  tensor(-4.9196, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0045, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.9241, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0874, 0.0050, 0.0319, 0.4363, 0.0095, 0.0179, 0.2238, 0.1303, 0.0028,
#         0.0006, 0.0544], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.694 seconds
# @----------------------------------------------------------@
# Batch number  173000
# Loss:  tensor(-4.6717, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0033, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.6750, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0812, 0.0055, 0.0330, 0.4817, 0.0105, 0.0192, 0.1969, 0.1162, 0.0030,
#         0.0006, 0.0521], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.869 seconds
# @----------------------------------------------------------@
# Batch number  174000
# Loss:  tensor(-5.0879, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0134, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.1013, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0843, 0.0057, 0.0369, 0.4459, 0.0120, 0.0224, 0.2201, 0.1055, 0.0034,
#         0.0007, 0.0630], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.703 seconds
# @----------------------------------------------------------@
# Batch number  175000
# Loss:  tensor(-4.2772, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0036, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2808, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0683, 0.0042, 0.0298, 0.4911, 0.0098, 0.0171, 0.2207, 0.1083, 0.0028,
#         0.0006, 0.0472], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.806 seconds
# @----------------------------------------------------------@
# Batch number  176000
# Loss:  tensor(-3.7612, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0110, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.7722, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0881, 0.0055, 0.0401, 0.4268, 0.0123, 0.0228, 0.2111, 0.1252, 0.0032,
#         0.0007, 0.0643], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.752 seconds
# @----------------------------------------------------------@
# Batch number  177000
# Loss:  tensor(-3.8822, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0079, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8901, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0954, 0.0073, 0.0404, 0.4091, 0.0154, 0.0244, 0.2096, 0.1288, 0.0043,
#         0.0008, 0.0644], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.680 seconds
# @----------------------------------------------------------@
# Batch number  178000
# Loss:  tensor(-4.0517, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0067, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0584, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0764, 0.0071, 0.0346, 0.4679, 0.0122, 0.0210, 0.2118, 0.1096, 0.0041,
#         0.0008, 0.0545], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.726 seconds
# @----------------------------------------------------------@
# Batch number  179000
# Loss:  tensor(-4.2473, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0134, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.2607, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0814, 0.0057, 0.0299, 0.4752, 0.0096, 0.0175, 0.2083, 0.1198, 0.0035,
#         0.0008, 0.0483], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.737 seconds
# @----------------------------------------------------------@
# Batch number  180000
# Loss:  tensor(-4.4514, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0109, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4623, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0775, 0.0053, 0.0296, 0.4839, 0.0089, 0.0172, 0.2155, 0.1102, 0.0030,
#         0.0006, 0.0483], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.813 seconds
# @----------------------------------------------------------@
# Batch number  181000
# Loss:  tensor(-4.5268, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0082, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5350, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0761, 0.0058, 0.0324, 0.4624, 0.0105, 0.0197, 0.2182, 0.1202, 0.0030,
#         0.0006, 0.0511], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.810 seconds
# @----------------------------------------------------------@
# Batch number  182000
# Loss:  tensor(-3.8553, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0062, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8615, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0832, 0.0050, 0.0322, 0.4658, 0.0101, 0.0191, 0.2144, 0.1112, 0.0025,
#         0.0005, 0.0559], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.829 seconds
# @----------------------------------------------------------@
# Batch number  183000
# Loss:  tensor(-5.3479, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0042, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-5.3521, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0960, 0.0045, 0.0364, 0.4312, 0.0089, 0.0191, 0.2112, 0.1268, 0.0021,
#         0.0004, 0.0633], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.743 seconds
# @----------------------------------------------------------@
# Batch number  184000
# Loss:  tensor(-4.5670, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0047, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5717, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0857, 0.0050, 0.0333, 0.4296, 0.0112, 0.0199, 0.2221, 0.1323, 0.0023,
#         0.0005, 0.0582], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.885 seconds
# @----------------------------------------------------------@
# Batch number  185000
# Loss:  tensor(-4.5283, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0029, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5313, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0801, 0.0053, 0.0304, 0.4910, 0.0105, 0.0181, 0.2045, 0.1065, 0.0024,
#         0.0005, 0.0507], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.693 seconds
# @----------------------------------------------------------@
# Batch number  186000
# Loss:  tensor(-4.7471, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0065, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.7536, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0862, 0.0073, 0.0372, 0.4383, 0.0139, 0.0235, 0.2136, 0.1193, 0.0036,
#         0.0007, 0.0566], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.755 seconds
# @----------------------------------------------------------@
# Batch number  187000
# Loss:  tensor(-4.8500, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0049, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.8549, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0738, 0.0070, 0.0335, 0.4712, 0.0113, 0.0202, 0.2173, 0.1105, 0.0032,
#         0.0006, 0.0514], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.689 seconds
# @----------------------------------------------------------@
# Batch number  188000
# Loss:  tensor(-4.4699, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0037, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4736, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0732, 0.0077, 0.0329, 0.4783, 0.0119, 0.0195, 0.2114, 0.1078, 0.0042,
#         0.0007, 0.0524], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.678 seconds
# @----------------------------------------------------------@
# Batch number  189000
# Loss:  tensor(-3.8916, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0136, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.9052, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0743, 0.0079, 0.0354, 0.4497, 0.0125, 0.0195, 0.2158, 0.1232, 0.0046,
#         0.0008, 0.0563], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.692 seconds
# @----------------------------------------------------------@
# Batch number  190000
# Loss:  tensor(-3.8092, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0070, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8163, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0820, 0.0060, 0.0304, 0.4637, 0.0092, 0.0166, 0.2196, 0.1179, 0.0035,
#         0.0007, 0.0504], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.678 seconds
# @----------------------------------------------------------@
# Batch number  191000
# Loss:  tensor(-4.4662, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0128, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4791, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0866, 0.0070, 0.0350, 0.4488, 0.0104, 0.0201, 0.2101, 0.1213, 0.0038,
#         0.0008, 0.0562], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.722 seconds
# @----------------------------------------------------------@
# Batch number  192000
# Loss:  tensor(-3.8128, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0055, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8184, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0694, 0.0058, 0.0282, 0.4940, 0.0097, 0.0170, 0.2188, 0.1062, 0.0034,
#         0.0006, 0.0470], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.658 seconds
# @----------------------------------------------------------@
# Batch number  193000
# Loss:  tensor(-4.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0039, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.0241, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0689, 0.0064, 0.0268, 0.5069, 0.0094, 0.0168, 0.2074, 0.1083, 0.0037,
#         0.0006, 0.0448], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.920 seconds
# @----------------------------------------------------------@
# Batch number  194000
# Loss:  tensor(-4.3793, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0039, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.3832, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0887, 0.0067, 0.0325, 0.4581, 0.0114, 0.0196, 0.2083, 0.1169, 0.0039,
#         0.0007, 0.0532], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.662 seconds
# @----------------------------------------------------------@
# Batch number  195000
# Loss:  tensor(-4.4404, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0061, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4465, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0892, 0.0054, 0.0328, 0.4584, 0.0101, 0.0185, 0.2119, 0.1132, 0.0030,
#         0.0005, 0.0571], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.649 seconds
# @----------------------------------------------------------@
# Batch number  196000
# Loss:  tensor(-4.5302, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0162, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.5464, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([8.2932e-02, 4.8904e-03, 3.6142e-02, 4.6232e-01, 1.0352e-02, 1.9163e-02,
#         2.0897e-01, 1.1365e-01, 2.5783e-03, 4.6164e-04, 5.8544e-02],
#        dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.697 seconds
# @----------------------------------------------------------@
# Batch number  197000
# Loss:  tensor(-3.8842, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0109, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.8951, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([8.5433e-02, 4.8293e-03, 3.5092e-02, 4.4007e-01, 1.0591e-02, 2.0782e-02,
#         2.1362e-01, 1.2811e-01, 2.0747e-03, 4.1740e-04, 5.8981e-02],
#        dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.625 seconds
# @----------------------------------------------------------@
# Batch number  198000
# Loss:  tensor(-3.9077, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0057, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-3.9134, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([7.8946e-02, 4.5999e-03, 3.0876e-02, 4.7443e-01, 9.9462e-03, 1.8437e-02,
#         2.1699e-01, 1.1229e-01, 1.9183e-03, 4.1617e-04, 5.1150e-02],
#        dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.737 seconds
# @----------------------------------------------------------@
# Batch number  199000
# Loss:  tensor(-4.4410, dtype=torch.float64, grad_fn=<AddBackward0>)
# Loss_orth:  tensor(0.0034, dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss_ML:  tensor(-4.4444, dtype=torch.float64, grad_fn=<MulBackward0>)
# Logits:  tensor([0.0735, 0.0054, 0.0329, 0.4639, 0.0108, 0.0196, 0.2164, 0.1242, 0.0022,
#         0.0005, 0.0507], dtype=torch.float64, grad_fn=<SoftmaxBackward>)
# Time taken: 2.687 seconds
# @----------------------------------------------------------@

# %%
plt.plot(np.arange(len(loss_hist)), loss_hist)
plt.title("Loss")
plt.show()
plt.plot(np.arange(len(loss_ML_hist)), loss_ML_hist)
plt.title("Loss_ML")
plt.show()
plt.plot(np.arange(len(loss_orth_hist)), loss_orth_hist)
plt.title("Loss_orth")
plt.show()

# %%
x = np.arange(-10, 10 , 0.01)

Y = HM(n_Hm, x)

SUP = np.matmul(Y, var_HC_N)

for i in range(n_EL+1):
    plt.plot(x, SUP[:, i])
    plt.title("Level " + str(i))
    plt.show()
    print("Square integrated over the region: " + str(np.sum(SUP[:, i] * SUP[:, i]) * 0.01)) #check wavefunction normalisation
# Out:
# Square integrated over the region: 1.000000000000022
# Square integrated over the region: 1.0000000000000224
# Square integrated over the region: 1.0000000000000218
# Square integrated over the region: 1.0000000000000215
# Square integrated over the region: 1.000000000000022
# Square integrated over the region: 1.000000000000022
# Square integrated over the region: 1.000000000000022
# Square integrated over the region: 1.0000000000000224
# Square integrated over the region: 1.0000000000000222
# Square integrated over the region: 1.0000000000000222
# Square integrated over the region: 1.000000000000023

# %%
for i in range(n_EL+1):
    plt.plot(np.arange(len(levels_hist[:,i])), levels_hist[:,i]*T, label = str(i))

plt.title("Energy levels")    
plt.legend()
plt.show()

for i in range(n_EL+1):
    plt.plot(np.arange(len(logits_hist[:,i])), logits_hist[:,i], label = str(i))

plt.title("Probability of mixed states")    
plt.legend()
plt.show()

# %%
print("Energy: ")
print(levels_fin)
print("Probabilities: ")
print(logits_fin)
# Out:
# Energy:
# [-1.10459419 -0.32024032  0.40416332  0.84590144  1.1960952   1.61876425
#   2.1517691   2.6525468   3.36807652  4.19255403  5.69303169]
# Probabilities:
# [0.48424648 0.22101712 0.10710788 0.06886158 0.04851653 0.03179266
#  0.01865717 0.01130735 0.00552854 0.00242406 0.00054062]

# %%
print(np.amax(np.abs(np.matmul(var_HC_N.T, var_HC_N) - np.identity(n_EL+1))))
# Out:
# 0.010854015221391929
